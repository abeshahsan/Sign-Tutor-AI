# %%
# Import test file - Testing various Python modules
# Standard Library Imports
print("Starting import test...")
import os
import sys
import json
import time
import datetime
import random
import math
import re
import logging
import argparse
import pathlib
import collections
import itertools
import functools

print("Standard libraries imported successfully.")

# Data Science and Machine Learning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

print("Data science libraries imported successfully.")

# Computer Vision and Image Processing
import cv2
import PIL
from PIL import Image, ImageDraw, ImageFont

print("Computer vision libraries imported successfully.")

# Deep Learning Frameworks
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

print("Deep learning libraries imported successfully.")

# Web and API related
import requests
import urllib.request
import flask
from flask import Flask, request, jsonify

print("Web and deep learning libraries imported successfully.")

# File handling and data formats
import yaml
import csv
import xml.etree.ElementTree as ET
import sqlite3

# GUI and Visualization
import tkinter as tk
from tkinter import filedialog, messagebox
import plotly.graph_objects as go
import plotly.express as px

# Utility libraries
import tqdm
from tqdm import tqdm
import pickle
import zipfile
import shutil
import glob

print("All utility libraries imported successfully.")

print("All imports successful!")
print(f"Python version: {sys.version}")
print(f"Current working directory: {os.getcwd()}")
print(f"Available modules imported: {len([name for name in globals() if not name.startswith('_')])}")
# Out:
# Starting import test...
# Standard libraries imported successfully.
# Data science libraries imported successfully.
# Computer vision libraries imported successfully.
# Deep learning libraries imported successfully.
# Web and deep learning libraries imported successfully.
# All utility libraries imported successfully.
# All imports successful!
# Python version: 3.10.18 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:08:55) [MSC v.1929 64 bit (AMD64)]
# Current working directory: f:\UNI_STUFF\8th Sem\Projects\PR\Sign-Language-Generation-From-Video-using-YOLOV5
# Available modules imported: 57

# %%
# !python app.py
# Out:
# ^C
# Fusing layers...
# custom_YOLOv5s summary: 232 layers, 7260003 parameters, 0 gradients
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: matplotlib>=3.3.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from ultralytics) (7.1.0)
# Collecting polars (from ultralytics)
#   Downloading polars-1.33.1-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in i:\myprogramnfiles\miniconda\envs\pr\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ----------------------------- ---------- 0.8/1.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.2 MB/s  0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Downloading polars-1.33.1-cp39-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 5.6 MB/s eta 0:00:07
#     --------------------------------------- 0.8/39.5 MB 1.9 MB/s eta 0:00:21
#     --------------------------------------- 0.8/39.5 MB 1.9 MB/s eta 0:00:21
#    - -------------------------------------- 1.6/39.5 MB 1.7 MB/s eta 0:00:23
#    - -------------------------------------- 1.8/39.5 MB 1.6 MB/s eta 0:00:24
#    -- ------------------------------------- 2.1/39.5 MB 1.6 MB/s eta 0:00:24
#    -- ------------------------------------- 2.4/39.5 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.6/39.5 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.9/39.5 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.1/39.5 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.4/39.5 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.7/39.5 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.9/39.5 MB 1.5 MB/s eta 0:00:25
#    ---- ----------------------------------- 4.2/39.5 MB 1.5 MB/s eta 0:00:25
#    ---- ----------------------------------- 4.7/39.5 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.0/39.5 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.2/39.5 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.5/39.5 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.8/39.5 MB 1.4 MB/s eta 0:00:24
#    ------ --------------------------------- 6.6/39.5 MB 1.5 MB/s eta 0:00:22
#    ------ --------------------------------- 6.8/39.5 MB 1.5 MB/s eta 0:00:22
#    ------- -------------------------------- 7.1/39.5 MB 1.5 MB/s eta 0:00:22
#    ------- -------------------------------- 7.1/39.5 MB 1.5 MB/s eta 0:00:22
#    ------- -------------------------------- 7.6/39.5 MB 1.5 MB/s eta 0:00:22
#    -------- ------------------------------- 8.1/39.5 MB 1.5 MB/s eta 0:00:21
#    -------- ------------------------------- 8.4/39.5 MB 1.5 MB/s eta 0:00:21
#    -------- ------------------------------- 8.7/39.5 MB 1.5 MB/s eta 0:00:21
#    --------- ------------------------------ 8.9/39.5 MB 1.5 MB/s eta 0:00:21
#    --------- ------------------------------ 9.2/39.5 MB 1.5 MB/s eta 0:00:21
#    --------- ------------------------------ 9.4/39.5 MB 1.5 MB/s eta 0:00:21
#    --------- ------------------------------ 9.7/39.5 MB 1.5 MB/s eta 0:00:21
#    ---------- ----------------------------- 10.0/39.5 MB 1.5 MB/s eta 0:00:20
#    ---------- ----------------------------- 10.2/39.5 MB 1.5 MB/s eta 0:00:20
#    ---------- ----------------------------- 10.5/39.5 MB 1.5 MB/s eta 0:00:20
#    ---------- ----------------------------- 10.7/39.5 MB 1.5 MB/s eta 0:00:20
#    ----------- ---------------------------- 11.0/39.5 MB 1.5 MB/s eta 0:00:20
#    ----------- ---------------------------- 11.3/39.5 MB 1.5 MB/s eta 0:00:20
#    ----------- ---------------------------- 11.5/39.5 MB 1.5 MB/s eta 0:00:20
#    ------------ --------------------------- 12.1/39.5 MB 1.5 MB/s eta 0:00:19
#    ------------ --------------------------- 12.6/39.5 MB 1.5 MB/s eta 0:00:18
#    ------------- -------------------------- 12.8/39.5 MB 1.5 MB/s eta 0:00:18
#    ------------- -------------------------- 13.1/39.5 MB 1.5 MB/s eta 0:00:18
#    ------------- -------------------------- 13.6/39.5 MB 1.5 MB/s eta 0:00:18
#    -------------- ------------------------- 13.9/39.5 MB 1.5 MB/s eta 0:00:17
#    -------------- ------------------------- 14.2/39.5 MB 1.5 MB/s eta 0:00:17
#    -------------- ------------------------- 14.4/39.5 MB 1.5 MB/s eta 0:00:17
#    -------------- ------------------------- 14.7/39.5 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 14.9/39.5 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 15.2/39.5 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 15.5/39.5 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 15.7/39.5 MB 1.5 MB/s eta 0:00:17
#    ---------------- ----------------------- 16.0/39.5 MB 1.5 MB/s eta 0:00:16
#    ---------------- ----------------------- 16.3/39.5 MB 1.5 MB/s eta 0:00:16
#    ---------------- ----------------------- 16.5/39.5 MB 1.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 16.8/39.5 MB 1.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 17.0/39.5 MB 1.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 17.3/39.5 MB 1.5 MB/s eta 0:00:16
#    ------------------ --------------------- 17.8/39.5 MB 1.5 MB/s eta 0:00:15
#    ------------------ --------------------- 18.4/39.5 MB 1.5 MB/s eta 0:00:15
#    ------------------- -------------------- 18.9/39.5 MB 1.5 MB/s eta 0:00:14
#    ------------------- -------------------- 18.9/39.5 MB 1.5 MB/s eta 0:00:14
#    ------------------- -------------------- 19.1/39.5 MB 1.5 MB/s eta 0:00:14
#    ------------------- -------------------- 19.7/39.5 MB 1.5 MB/s eta 0:00:14
#    -------------------- ------------------- 19.9/39.5 MB 1.5 MB/s eta 0:00:14
#    -------------------- ------------------- 20.2/39.5 MB 1.5 MB/s eta 0:00:13
#    -------------------- ------------------- 20.4/39.5 MB 1.5 MB/s eta 0:00:13
#    -------------------- ------------------- 20.7/39.5 MB 1.5 MB/s eta 0:00:13
#    --------------------- ------------------ 21.0/39.5 MB 1.5 MB/s eta 0:00:13
#    --------------------- ------------------ 21.2/39.5 MB 1.5 MB/s eta 0:00:13
#    --------------------- ------------------ 21.5/39.5 MB 1.5 MB/s eta 0:00:13
#    ---------------------- ----------------- 21.8/39.5 MB 1.5 MB/s eta 0:00:12
#    ---------------------- ----------------- 22.0/39.5 MB 1.5 MB/s eta 0:00:12
#    ---------------------- ----------------- 22.3/39.5 MB 1.5 MB/s eta 0:00:12
#    ---------------------- ----------------- 22.5/39.5 MB 1.5 MB/s eta 0:00:12
#    ----------------------- ---------------- 22.8/39.5 MB 1.5 MB/s eta 0:00:12
#    ----------------------- ---------------- 23.3/39.5 MB 1.5 MB/s eta 0:00:11
#    ------------------------ --------------- 23.9/39.5 MB 1.5 MB/s eta 0:00:11
#    ------------------------ --------------- 24.1/39.5 MB 1.5 MB/s eta 0:00:11
#    ------------------------ --------------- 24.4/39.5 MB 1.5 MB/s eta 0:00:11
#    ------------------------ --------------- 24.6/39.5 MB 1.5 MB/s eta 0:00:11
#    ------------------------- -------------- 25.2/39.5 MB 1.5 MB/s eta 0:00:10
#    ------------------------- -------------- 25.4/39.5 MB 1.5 MB/s eta 0:00:10
#    -------------------------- ------------- 25.7/39.5 MB 1.5 MB/s eta 0:00:10
#    -------------------------- ------------- 26.0/39.5 MB 1.5 MB/s eta 0:00:10
#    -------------------------- ------------- 26.2/39.5 MB 1.5 MB/s eta 0:00:09
#    -------------------------- ------------- 26.5/39.5 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 26.7/39.5 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 27.0/39.5 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 27.0/39.5 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 27.3/39.5 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 27.5/39.5 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 27.8/39.5 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 28.0/39.5 MB 1.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 28.3/39.5 MB 1.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 28.6/39.5 MB 1.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 28.8/39.5 MB 1.4 MB/s eta 0:00:08
#    ------------------------------ --------- 29.6/39.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------------ --------- 29.9/39.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------------ --------- 30.1/39.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------------ --------- 30.4/39.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------------- -------- 30.7/39.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------------- -------- 30.9/39.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------------- -------- 31.2/39.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------------- -------- 31.5/39.5 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 31.7/39.5 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 32.0/39.5 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 32.5/39.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 32.8/39.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 33.0/39.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 33.3/39.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 33.3/39.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 33.3/39.5 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.6/39.5 MB 1.4 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.6/39.5 MB 1.4 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.8/39.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 34.1/39.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 34.3/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 34.6/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 34.6/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 34.9/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 35.1/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 35.1/39.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 35.4/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 35.7/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 35.7/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 35.9/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 36.2/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 36.2/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 36.4/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 36.7/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 36.7/39.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 37.0/39.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 37.2/39.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 37.2/39.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 37.5/39.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 37.7/39.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 37.7/39.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 38.0/39.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 38.3/39.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 1.3 MB/s  0:00:30
# Installing collected packages: polars, ultralytics-thop, ultralytics
#
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    ---------------------------------------- 0/3 [polars]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    -------------------------- ------------- 2/3 [ultralytics]
#    ---------------------------------------- 3/3 [ultralytics]
#
# Successfully installed polars-1.33.1 ultralytics-8.3.203 ultralytics-thop-2.0.17
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\abesh\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Loading model from: f:\UNI_STUFF\8th Sem\Projects\PR\Sign-Language-Generation-From-Video-using-YOLOV5\weights/yolov5_v0.pt
# AI Model loaded successfully from f:\UNI_STUFF\8th Sem\Projects\PR\Sign-Language-Generation-From-Video-using-YOLOV5\weights/yolov5_v0.pt
# Model has 6 classes: ['Hello', 'IloveYou', 'No', 'Please', 'Thanks', 'Yes']
